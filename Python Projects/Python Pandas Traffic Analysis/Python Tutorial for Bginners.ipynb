# %% [markdown]
# # Python Tutorial for Absolute Beginners
# [Python Tutorial for Absolute Beginners](https://goo.gl/4dQMsJ)
#
# ![Why leave Google? Former Googlers on how they knew it was time to quit](https://i.insider.com/5bc6267d9311df164c3c7bf4?width=600&format=jpeg&auto=webp)
#
# This playlist has 16 explainer videos from CS Dojo. Instructor’s name is YK Sugi. He is a Vancouver-based software developer / data scientist / product manager and very good explainer. His YouTube channel CS Dojo has 1.6 million subscribers! The [first video](https://www.youtube.com/watch?v=Z1Yd7upQsXY&t=315s) of Python Tutorial for Absolute Beginners attracts 6 million views and is increasing! Please watch the first 14 videos and practice after YK to get warmed up to Python fundamentals.

# %% [markdown]
# # 1. Variables

# %%
print("Hello World")

# %%
print("more string")
print(3)

# %%
a = 1
b = 2
c = "hello there"
print(a)
print(b)
print(c)

# %%
b = 1
print(b)

# %%
print(e)

# %%
e = "this is a string"
print(e)

# %%
f = a
print(f)

# %%
a = 2
print(a)
print(f)

# %%
# swapping two variables
v1 = "first string"
v2 = "second string"
temp = v1
v1 = v2
v2 = temp
print(v1)
print(v2)

# %% [markdown]
# # 2. If Else

# %%
a = 1
b = 2
if a < b:
    print("a is less than b")

# %%
c = 5
d = 4
if c < d:
    print("c is less than d")
else:
    print("c is NOT less than d")

# %%
e = 20
f = 8
if e < f:
    print("e is less than f")
elif e == f:
    print("e is equal to f")
else:
    print("e is greater than f")

# %%
g = 9
h = 8
if g < h:
    print("g is less than h")
else:
    if g == h:
        print("g is equal to h")
    else:
        print("g is greater than h")

# %%
# Body mass index (BMI)
name = "YK"
height_m = 2
weight_kg = 110

bmi = weight_kg / (height_m ** 2)
print("bmi: ")
print(bmi)
if bmi < 25:
    print(name)
    print("is not overweight")
else:
    print(name)
    print("is overweight")

# %% [markdown]
# # 3. Functions

# %%
# a collection of instructions
# a collection of code
def function1():
    print("ahhhh")
    print("ahhhhh 2")
function1()

# %%
# a mapping
# input or an argument
def function2(x):
    return 2 * x
# return value or output
a = function2(3)
print(a)
b = function2(4)
print(b)
c = function2(5)
print(c)

# %%
d = function2()

# %%
def function3(x, y):
    return x + y
e = function3(1, 2)
print(e)

# %%
def function4(x):
    print(x)
    return 3 * x
f = function4(4)
print(f)

# %%
def function5(some_argument):
    print(some_argument)
    print("weeee")
function5(4)

# %%
# BMI calculator
name1 = "YK"
height_m1 = 2
weight_kg1 = 90

name2 = "YK's sister"
height_m2 = 1.8
weight_kg2 = 70

name3 = "YK's brother"
height_m3 = 2.5
weight_kg3 = 160

# %%
def bmi_calculator(name, height_m, weight_kg):
    bmi = weight_kg / (height_m ** 2)
    print("bmi: ")
    print(bmi)
    if bmi < 25:
        return name + " is not overweight"
    else:
        return name + " is overweight"

# %%
result1 = bmi_calculator(name1, height_m1, weight_kg1)
result2 = bmi_calculator(name2, height_m2, weight_kg2)
result3 = bmi_calculator(name3, height_m3, weight_kg3)
print(result1)
print(result2)
print(result3)

# %%
# convert miles to kilometers: kilometers = 1.6 * miles
def convert(miles):
    return 1.6 * miles
print(convert(1))
print(convert(2))

# %% [markdown]
# # 4. Lists

# %%
a = [3, 10, -1]
print(a)

# %%
a.append(1)
print(a)

# %%
a.append("hello")
print(a)

# %%
a.append([1, 2])
print(a)

# %%
a.pop()
print(a)

# %%
a.pop()
print(a)

# %%
print(a[0])

# %%
print(a[3])

# %%
a[0] = 100

# %%
print(a)

# %%
b = ["banana", "apple", "microsoft"]
print(b)

# %%
# swap
temp = b[0]
b[0] = b[2]
b[2] = temp
print(b)

# %%
# swap back
b[0], b[2] = b[2], b[0]
print(b)

# %% [markdown]
# # 5. For Loops

# %%
a = ["banana", "apple", "microsoft"]
for element in a:
    print(element)
    print(element)

# %%
b = [20, 10, 5]
total = 0
for e in b:
    total = total + e
print(total)

# %%
# 1, 2, 3, 4
c = list(range(1, 5))
print(c)

# %%
total2 = 0
for i in range(1, 5):
    total2 += i
print(total2)

# %%
print(list(range(1, 8)))

# %%
print(4 % 3)
print(5 % 3)
print(1 % 3)
print(6 % 3)

# %%
total3 = 0
for i in range(1, 8):
    if i % 3 == 0:
        total3 += i
print(total3)

# %%
# compute all multiples of 3, 5 that are less than 100?
print(list(range(1, 100)))

# %% [markdown]
# # 6. While Loops and Breaks

# %%
total = 0
for i in range(1, 5):
    total += i
print(total)

# %%
total2 = 0
j = 1
while j < 5:
    total2 += j
    j += 1
print(total2)

# %%
given_list = [5, 4, 4, 3, 1]
total3 = 0
i = 0
while i < len(given_list) and given_list[i] > 0:
    total3 += given_list[i]
    i += 1
print(total3)

# %%
given_list2 = [5, 4, 4, 3, 1, -2, -3, -5]
total4 = 0
for element in given_list2:
    if element <= 0:
        break
    total4 += element
print(total4)

# %%
# given_list2 = [5, 4, 4, 3, 1, -2, -3, -5]
total5 = 0
i = 0
while True:
    total5 += given_list2[i]
    i += 1
    if given_list2[i] <= 0:
        break
print(total5)

# %%
# sum of negatives
given_list3 = [7, 5, 4, 4, 3, 1, -2, -3, -5, -7]

# %% [markdown]
# # 7. More For Loops

# %%
a = ["apple", "banana", "republic"]
for element in a:
    print(element)

# %%
for i in range(len(a)): # 0, 1, 2
    for j in range(i + 1):
        # i = 0 -> j = 0
        # i = 1 -> j = 0, 1
        # i = 2 -> j = 0, 1, 2
        print(a[i])

# %%
# compute the sum of all multiples of 3 and 5 that are less than 100?
print(list(range(1, 100)))

# %%
total = 0
for i in range(1, 100):
    if i % 3 == 0 or i % 5 == 0:
        total += i
print(total)

# %%
# sum of negatives
given_list = [7, 5, 4, 4, 3, 1, -2, -3, -5, -7]

total2 = 0
j = len(given_list) - 1
while given_list[j] < 0:
    total2 += given_list[j]
    j -= 1
print(total2)

# %% [markdown]
# # 8. Dictionaries

# %%
d = {}
# d = {"George": 24, "Tom": 32}

# %%
d["George"] = 24
d["Tom"] = 32
d["Jenny"] = 16
print(d["George"])
print(d["Tom"])
print(d["Jenny"])
print(d["Alice"])

# %%
d["Jenny"] = 20
print(d["Jenny"])

# %%
# keys are commonly strings or numbers
d[10] = 100
print(d[10])

# %%
# how to iterate over key-value pairs?
for key, value in d.items():
    print("key:")
    print(key)
    print("value:")
    print(value)
    print("")

# %% [markdown]
# # 9-10. Classes and Objects

# %%
class Robot:
    def __init__(self, name, color, weight):
        self.name = name
        self.color = color
        self.weight = weight

    def introduce_self(self):
        print("My name is " + self.name) # this in Java

# %%
# r1 = Robot()
# r1.name = "Tom"
# r1.color = "red"
# r1.weight = 30

# r2 = Robot()
# r2.name = "Jerry"
# r2.color = "blue"
# r2.weight = 40

r1 = Robot("Tom", "red", 30)
r2 = Robot("Jerry", "blue", 40)

# %%
r1.introduce_self()
r2.introduce_self()

# %%
class Robot:
    def __init__(self, n, c, w):
        self.name = n
        self.color = c
        self.weight = w
    
    def introduce_self(self):
        print("My name is " + self.name)

# %%
r1 = Robot("Tom", "red", 30)
r2 = Robot("Jerry", "blue", 40)

# %%
class Person:
    def __init__(self, n, p, i):
        self.name = n
        self.personality = p
        self.is_sitting = i
    
    def sit_down(self):
        self.is_sitting = True
    
    def stand_up(self):
        self.is_sitting = False

# %%
p1 = Person("Alice", "aggressive", False)
p2 = Person("Becky", "talkative", True)

# %%
# p1 owns r2
p1.robot_owned = r2
p2.robot_owned = r1

# %%
p1.robot_owned.introduce_self()

# %% [markdown]
# # 11. Boolean

# %%
type("Microsoft")

# %%
type(4)

# %%
type(True)

# %%
a = 3
b = 1

# %%
if a > 6:
    print("a is greater than b")

# %%
boolean_value = a > b

# %%
print(boolean_value)

# %%
if boolean_value:
    print("a is greater than b")

# %%
def are_you_sad(is_rainy, has_umbrella):
    return is_rainy and not has_umbrella

# %%
are_you_sad(True, False)

# %%
are_you_sad(True, True)

# %%
def c_greater_than_d_plus_e(c, d, e):
    return c > d + e

# %%
c_greater_than_d_plus_e(3, 1, 1)

# %%
c_greater_than_d_plus_e(3, 1, 2)

# %% [markdown]
# # 12. List Comprehensions

# %%
a = [1, 3, 5, 7, 9, 11]

# %%
# [2, 6, 10, 14, 18, 22]

# %%
# .append()

# %%
b = []
b.append(10)
b.append(20)
print(b)

# %%
c = []
for x in a:
    c.append(x * 2)
print(c)
# Out:
# [2, 6, 10, 14, 18, 22]

# %%
d = [x * 2 for x in a]
print(d)

# %%
# [1, 4, 9, 16, 25, 36]
e1 = []
for x in range(1, 7):
    e1.append(x ** 2)
print(e1)

# %%
e2 = [x ** 2 for x in range(1, 7)]
print(e2)

# %%
# [36, 25, 16, 9, 4, 1]
for x in range(6, 0, -1):
    print(x)

# %%
f1 = []
for x in range(6, 0, -1):
    f1.append(x**2)
print(f1)

# %%
f2 = [x**2 for x in range(6, 0, -1)]
print(f2)

# %% [markdown]
# # 13. Set

# %%
# a set is a type of data that stores a set of unique things.

# %%
a = set()
print(a)

# %%
a.add(1)
print(a)

# %%
a.add(2)
print(a)

# %%
a.add(2)
print(a)

# %%
for x in a:
    print(x)

# %%
given_list1 = [1, 1, 2, 4, 2]

# %%
new_set1 = set ()
for x in given_list1:
    new_set1.add(x)
print(new_set1)

# %%
new_list1 = list()
for x in new_set1:
    new_list1.append(x)
print(new_list1)

# %%
b = set()
b.add('apple')
b.add('banana')
b.add(1)
print(b)

# %%
given_list2 = [1, 3, 4, 1, 3]
new_set2 = set()
for x in given_list2:
    new_set2.add(x)
total = 0
for x in new_set2:
    total += x
print(total)

# %% [markdown]
# # 14. CodingBat

# %%
# sleep_in
def sleep_in(weekday, vacation):
    return not weekday or vacation

# %%
# string_times
def string_times(str, n):
    return str * n
string_times('hi', 4)

# %%
# hello_name
def hello_name(name):
    return 'Hello ' + name + '!'
hello_name('Bob')

# %%
# first_last6
def first_last6(nums):
    return nums[0] == 6 or nums[-1] == 6
first_last6([1, 2, 6])

# %%
# double_char
def double_char(str):
    to_return = ''
    for c in str:
        to_return += c*2
    return to_return
double_char('The')

# %%
# count_evens
def count_evens(nums):
    count = 0
    for x in nums:
        if x % 2 == 0:
            count += 1
    return count
count_evens([2, 1, 2, 3, 4])
